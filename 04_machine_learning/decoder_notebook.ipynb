# %% [markdown]
# # Decoder notebook
#
# This notebook accompanies `neural_decoder.py`.
#
# To run the script:
#
# ```bash
# python neural_decoder.py
# ```
#
# The script simulates neural population activity under two conditions, trains a logistic regression decoder (scikit-learn), and reports accuracy with a confusion matrix and a 2D visualisation.
